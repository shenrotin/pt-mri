# %%
from pt_mri.pico.Picoscope import Picoscope
from pt_mri.pico.ChannelConfig import ChannelConfig
import matplotlib.pyplot as plt

# %%
channel_configs=[]
channel_configs.append(ChannelConfig("A"))
channel_configs.append(ChannelConfig("B"))
channel_configs.append(ChannelConfig("C"))
channel_configs.append(ChannelConfig("D"))

pico=Picoscope()
pico.connect(10000, 200, channel_configs)

# %%
traces=pico.get_traces()

# %%
[plt.plot(trace) for trace in traces]
plt.show()
